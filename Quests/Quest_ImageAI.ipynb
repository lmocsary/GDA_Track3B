# %% [markdown]
# # Preparation

# %% [markdown]
# Install ImageAI.

# %%
# !pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl
# Out:
# Requirement already satisfied: imageai==2.0.2 from https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl in /root/venv/lib/python3.7/site-packages (2.0.2)
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Download the weights generated by the ResNet model, trained on the ImageNet dataset.

# %%
import urllib.request
import os
urllib.request.urlretrieve('https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5', 'resnet.h5')
# Out:
# ('resnet.h5', <http.client.HTTPMessage at 0x7ff0cd0f3c90>)

# %% [markdown]
# Download the picture which we will ateempt to classify using the model.

# %%
urllib.request.urlretrieve('https://upload.wikimedia.org/wikipedia/commons/b/bb/Kittyply_edit1.jpg','cat.jpg')
# Out:
# ('cat.jpg', <http.client.HTTPMessage at 0x7ff0cd0f6490>)

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

h= 300
w= int(round(1.618*h,0))

test_image = load_img("cat.jpg", target_size = (h,w))
test_image
# Out:
# <PIL.Image.Image image mode=RGB size=485x300 at 0x7FF05FAFFD50>

# %% [markdown]
# # Tasks

# %% [markdown]
# Refer to the ImageAI [documentation](https://imageai.readthedocs.io/en/latest/) to complete the tasks.
#
# *   Create an instance of `ImagePrediction()`.
# *   Since we will be using weights trained on ResNet, set the model type to ResNet.
# *   Set model path to the pre-trained weights you downloaded earlier.
# *   Finally, load the model.

# %%
# your code:
from imageai.Prediction import ImagePrediction

prediction = ImagePrediction()
prediction.setModelTypeAsResNet()
prediction.setModelPath("resnet.h5")
prediction.loadModel()

# %% [markdown]
# Return top 3 predictions and their corresponding probabilities for the image.

# %%
# your code:
predictions, probabilities = prediction.predictImage("cat.jpg", result_count=3)
for pred, p in zip(predictions, probabilities):
    print(pred + " : " ,round(p,1))
# Out:
# tabby :  50.0
# Egyptian_cat :  21.7
# tiger_cat :  20.6

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a109ea11-a7da-42aa-8af0-3a0cdafc917e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
